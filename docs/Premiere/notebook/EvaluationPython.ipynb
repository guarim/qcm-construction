# %% [markdown]
# #  <span style="color:darkred;"> &#10070; Evaluation de programmation Python (07-08 octobre 2010) </span>
#
# ## <span style="color:darkblue;"> &diams; Préambule</span>

# %% [markdown]
# On rappelle ci-dessous les instructions Python permettant d'importer le module `turtle` et de créer le `crayon` et le `papier` virutel.
#
# **Exécuter ces instructions** afin de disposer ce ces outils avant de commencer l'évaluation

# %%
import turtle
crayon = turtle.Turtle()
papier = turtle.Screen()

# %% [markdown]
# On rappelle que le repère et la grille qui figurent sur les dessins sont là pour vous aider et ne doivent pas être reproduits.

# %% [markdown]
# ## <span style="color:darkblue;"> &diams; Exercice 1</span>
#
# Réaliser le dessin suivant en utilisant un crayon de couleur `darkred` et d'épaisseur 5 sur un papier de couleur `lightgray` :

# %% [markdown]
# ![img_eval1.png](attachment:img_eval1.png)

# %%
# Taper votre programme ici

# %% [markdown]
# ## <span style="color:darkblue;"> &diams; Exercice 2</span>
#
# En utilisant **une boucle `for`**, modifier votre programme de façon à répéter le dessin de ce motif pour obtenir la frise suivante :

# %% [markdown]
# ![img_eval2.png](attachment:img_eval2.png)

# %% [markdown]
# ## <span style="color:darkblue;"> &diams; Exercice 3</span>

# %% [markdown]
# Modifier votre programme en y incluant une **instruction conditionnelle** de façon à ce que le troisème motif tracé soit de couleur `navy` :

# %% [markdown]
# ![img_eval3.png](attachment:img_eval3.png)

# %%
# Taper votre programme ici

# %% [markdown]
# ## <span style="color:darkblue;"> &diams; Exercice 4</span>

# %% [markdown]
# 1. Ecrire une fonction `carre_cercle(x,y,r)` qui trace un carre de côté `r` et dont le coin inférieur gauche se situe en `(x,y)` et  le cercle inscrit dans ce carré, c'est à dire le cercle  de rayon `r/2` et dont le centre est le centre du carré.
#
# Sur l'exemple suivant, la fonction est utilisée en (0,0) et le côté du carré mesure 100 pixels.

# %% [markdown]
# ![img_eval4.png](attachment:img_eval4.png)

# %% [markdown]
# 2. En utilisant cette fonction, reproduire la figure suivante :

# %% [markdown]
# ![img_eval6.png](attachment:img_eval6.png)

# %%
# A exécuter pour fermer la fenêtre de dessin
papier.bye()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a7dc28b40b2f> in <module>
#       1 # A exécuter pour fermer la fenêtre de dessin
# ----> 2 feuille.bye()
#
# NameError: name 'feuille' is not defined
